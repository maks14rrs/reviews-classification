# %%
import pandas as pd
import re

# %%
texts = [
    # === POSITIVE (20 отзывов) ===
    "Отличный сервис, всё быстро и удобно",
    "Очень понравилось качество, буду заказывать ещё",
    "Доставка приехала вовремя, товар супер",
    "Хорошая поддержка, помогли решить вопрос",
    "Прекрасное приложение, всё понятно",
    "Классный магазин, цены адекватные",
    "Заказ пришёл быстро, упаковка отличная",
    "Качество на высоте, рекомендую всем",
    "Очень доволен покупкой, спасибо!",
    "Сервис просто супер, всё идеально",
    "Товар соответствует описанию, отлично",
    "Быстрая доставка, вежливый курьер",
    "Отличное качество за свои деньги",
    "Магазин просто находка, буду постоянным клиентом",
    "Поддержка отвечает моментально, всё решили",
    "Приложение удобное, интерфейс понятный",
    "Цены ниже, чем у конкурентов, супер",
    "Упаковали аккуратно, ничего не помялось",
    "Курьер приехал точно в срок, молодец",
    "Очень хороший магазин, всем советую",
    
    # === NEGATIVE (20 отзывов) ===
    "Ужасное качество, всё сломалось через день",
    "Доставка опоздала, товар пришёл повреждённым",
    "Плохая поддержка, никто не отвечает",
    "Не рекомендую, деньги на ветер",
    "Приложение постоянно вылетает",
    "Очень плохо упаковали, всё помялось",
    "Заказ не пришёл вообще, мошенники",
    "Качество отвратительное, верните деньги",
    "Поддержка хамит, ничего не помогли",
    "Доставка опоздала на две недели",
    "Товар не соответствует описанию",
    "Цены завышены, качество ужасное",
    "Курьер нагрубил, больше не закажу",
    "Приложение глючит, невозможно пользоваться",
    "Упаковка была порвана, товар повреждён",
    "Сервис отвратительный, никто не помогает",
    "Заказ пришёл с браком, очень разочарован",
    "Магазин обманывает покупателей",
    "Поддержка не отвечает уже неделю",
    "Худший магазин, в котором я покупал",
    
    # === NEUTRAL (20 отзывов) ===
    "Заказ пришёл как обычно, без сюрпризов",
    "Обычный товар, соответствует описанию",
    "Доставка средняя, ни быстро ни медленно",
    "Сервис нормальный, ничего особенного",
    "Цена обычная, качество среднее",
    "Всё стандартно, как в прошлый раз",
    "Товар нормальный, ничего особенного",
    "Доставка обычная, как и обещали",
    "Поддержка отвечает, но не быстро",
    "Приложение работает, но есть баги",
    "Качество приемлемое за эту цену",
    "Упаковка обычная, ничего особенного",
    "Курьер приехал вовремя, всё нормально",
    "Магазин обычный, ничего особенного",
    "Сервис работает, но можно лучше",
    "Товар соответствует цене, нормально",
    "Доставка заняла столько, сколько обещали",
    "Поддержка помогла, но долго отвечали",
    "Всё как обычно, без проблем",
    "Нормальный магазин, буду заказывать ещё"
]

labels = [
    "positive"] * 20 + ["negative"] * 20 + ["neutral"] * 20

df = pd.DataFrame({
    "text": texts,
    "label": labels
})

print(f"Всего отзывов: {len(df)}")
print("\nРаспределение по классам:")
print(df["label"].value_counts())
# Out:
# Всего отзывов: 60
#
# Распределение по классам:
# label
# positive    20
# negative    20
# neutral     20
# Name: count, dtype: int64

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^а-яёa-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
df["clean_text"] = df["text"].apply(clean_text)

print(df.columns.tolist())
print(df.head())
# Out:
# ['text', 'label', 'clean_text']
#                                               text     label  \
# 0             Отличный сервис, всё быстро и удобно  positive
# 1  Очень понравилось качество, буду заказывать ещё  positive
# 2           Доставка приехала вовремя, товар супер  positive
# 3         Хорошая поддержка, помогли решить вопрос  positive
# 4               Прекрасное приложение, всё понятно  positive
#
#                                        clean_text
# 0             отличный сервис всё быстро и удобно
# 1  очень понравилось качество буду заказывать ещё
# 2           доставка приехала вовремя товар супер
# 3         хорошая поддержка помогли решить вопрос
# 4               прекрасное приложение всё понятно

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df["clean_text"],
    df["label"],
    test_size=0.33,
    random_state=42,
    stratify=df["label"]
)

# %%
df["clean_text"] = df["text"].apply(clean_text)

print(df[["text", "clean_text"]].head())
# Out:
#                                               text  \
# 0             Отличный сервис, всё быстро и удобно
# 1  Очень понравилось качество, буду заказывать ещё
# 2           Доставка приехала вовремя, товар супер
# 3         Хорошая поддержка, помогли решить вопрос
# 4               Прекрасное приложение, всё понятно
#
#                                        clean_text
# 0             отличный сервис всё быстро и удобно
# 1  очень понравилось качество буду заказывать ещё
# 2           доставка приехала вовремя товар супер
# 3         хорошая поддержка помогли решить вопрос
# 4               прекрасное приложение всё понятно

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
model = Pipeline([
    ("tfidf", TfidfVectorizer(ngram_range=(1, 2), min_df=2)),
    ("classifier", LogisticRegression(max_iter=1000))
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(min_df=2, ngram_range=(1, 2))),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %%
predictions = model.predict(X_test)

# %%
result = pd.DataFrame({
    "true": y_test,
    
    "predicted": predictions,
    "text": X_test
})

print(result)
# Out:
#         true predicted                                             text
# 19  positive  negative               очень хороший магазин всем советую
# 41   neutral  positive             обычный товар соответствует описанию
# 34  negative  positive            упаковка была порвана товар повреждён
# 29  negative   neutral                  доставка опоздала на две недели
# 17  positive  negative           упаковали аккуратно ничего не помялось
# 11  positive   neutral                 быстрая доставка вежливый курьер
# 13  positive  negative  магазин просто находка буду постоянным клиентом
# 27  negative  positive           качество отвратительное верните деньги
# 48   neutral  negative                  поддержка отвечает но не быстро
# 40   neutral  negative            заказ пришёл как обычно без сюрпризов
# 50   neutral  positive                  качество приемлемое за эту цену
# 57   neutral   neutral              поддержка помогла но долго отвечали
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Accuracy:", accuracy_score(y_test, predictions))
print()
print(confusion_matrix(y_test, predictions))
print()
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.3
#
# [[3 1 2]
#  [2 3 2]
#  [6 1 0]]
#
#               precision    recall  f1-score   support
#
#     negative       0.27      0.50      0.35         6
#      neutral       0.60      0.43      0.50         7
#     positive       0.00      0.00      0.00         7
#
#     accuracy                           0.30        20
#    macro avg       0.29      0.31      0.28        20
# weighted avg       0.29      0.30      0.28        20

# %%
errors = result[result["true"] != result["predicted"]]

print(errors)
# Out:
#         true predicted                                             text
# 19  positive  negative               очень хороший магазин всем советую
# 41   neutral  positive             обычный товар соответствует описанию
# 34  negative  positive            упаковка была порвана товар повреждён
# 29  negative   neutral                  доставка опоздала на две недели
# 17  positive  negative           упаковали аккуратно ничего не помялось
# 11  positive   neutral                 быстрая доставка вежливый курьер
# 13  positive  negative  магазин просто находка буду постоянным клиентом
# 27  negative  positive           качество отвратительное верните деньги
# 48   neutral  negative                  поддержка отвечает но не быстро
# 40   neutral  negative            заказ пришёл как обычно без сюрпризов
# 50   neutral  positive                  качество приемлемое за эту цену
# 8   positive  negative                   очень доволен покупкой спасибо
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# %%
models = {
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "MultinomialNB": MultinomialNB(),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42)
}

for name, classifier in models.items():
    pipe = Pipeline([
        ("tfidf", TfidfVectorizer(ngram_range=(1, 2), min_df=1)),
        ("classifier", classifier)
    ])

    pipe.fit(X_train, y_train)
    pred = pipe.predict(X_test)

    print(name)
    print("Accuracy:", accuracy_score(y_test, pred))
    print()
# Out:
# LogisticRegression
# Accuracy: 0.3
#
# MultinomialNB
# Accuracy: 0.3
#
# RandomForest
# Accuracy: 0.3

# %%
from sklearn.metrics import confusion_matrix, classification_report

print("\n=== LogisticRegression ===")
print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))
print("\nClassification Report:")
print(classification_report(y_test, predictions))
# Out:
# === LogisticRegression ===
# Confusion Matrix:
# [[3 0 3]
#  [3 2 2]
#  [5 1 1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.27      0.50      0.35         6
#      neutral       0.67      0.29      0.40         7
#     positive       0.17      0.14      0.15         7
#
#     accuracy                           0.30        20
#    macro avg       0.37      0.31      0.30        20
# weighted avg       0.37      0.30      0.30        20

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# --- ПРОВЕРКА 1: метки стоят напротив своих текстов? ---
print("=== Граница positive/negative (строки 18-21) ===")
print(df.iloc[18:22][["text", "label"]])
print()
print("=== Граница negative/neutral (строки 38-41) ===")
print(df.iloc[38:42][["text", "label"]])
print()

# --- ПРОВЕРКА 2: модель хотя бы train может выучить? ---
diag = Pipeline([
    ("tfidf", TfidfVectorizer(ngram_range=(1, 2), min_df=1)),
    ("clf", LogisticRegression(max_iter=1000))
])
diag.fit(X_train, y_train)

train_pred = diag.predict(X_train)
test_pred = diag.predict(X_test)

print("=== Train accuracy (на обучении):", accuracy_score(y_train, train_pred))
print("=== Test accuracy (на тесте):   ", accuracy_score(y_test, test_pred))
print()

# --- ПРОВЕРКА 3: что модель вообще предсказывает? ---
print("=== Распределение предсказаний на тесте ===")
print(pd.Series(test_pred).value_counts())
print()
print("=== Confusion matrix ===")
print(confusion_matrix(y_test, test_pred, labels=["positive", "negative", "neutral"]))
# Out:
# === Граница positive/negative (строки 18-21) ===
#                                             text     label
# 18          Курьер приехал точно в срок, молодец  positive
# 19           Очень хороший магазин, всем советую  positive
# 20    Ужасное качество, всё сломалось через день  negative
# 21  Доставка опоздала, товар пришёл повреждённым  negative
#
# === Граница negative/neutral (строки 38-41) ===
#                                       text     label
# 38        Поддержка не отвечает уже неделю  negative
# 39     Худший магазин, в котором я покупал  negative
# 40  Заказ пришёл как обычно, без сюрпризов   neutral
# 41   Обычный товар, соответствует описанию   neutral
#
# === Train accuracy (на обучении): 1.0
# === Test accuracy (на тесте):    0.3
#
# === Распределение предсказаний на тесте ===
# negative    11
# positive     6
# neutral      3
# Name: count, dtype: int64
#
# === Confusion matrix ===
# [[1 5 1]
#  [3 3 0]
#  [2 3 2]]

# %%
df_bin = df[df["label"] != "neutral"].copy()

Xb_train, Xb_test, yb_train, yb_test = train_test_split(
    df_bin["clean_text"],
    df_bin["label"],
    test_size=0.3,
    random_state=42,
    stratify=df_bin["label"]
)

bin_pipe = Pipeline([
    ("tfidf", TfidfVectorizer(ngram_range=(1, 2), min_df=1)),
    ("clf", LogisticRegression(max_iter=1000))
])
bin_pipe.fit(Xb_train, yb_train)

print("Binary accuracy (pos vs neg):", accuracy_score(yb_test, bin_pipe.predict(Xb_test)))
# Out:
# Binary accuracy (pos vs neg): 0.4166666666666667
